# %%
#from rauth import OAuth1Service
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
tracks = pd.read_csv('tracks_with_audio_features.csv')

# %%
album = pd.read_csv('albums.csv')

# %%
album.loc[album.release_date > '2016-12-01'].shape
# Out:
# (2303, 7)

# %%
album.shape
# Out:
# (5222, 7)

# %%
tracks.head()
# Out:
#                  album_id                                  available_markets  \
# 0  5UwAcPkrtvw2YI9Z1GM4Um  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...
# 1  2ndOu6utnBQdy2MAbuDoEP  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...
# 2  2ndOu6utnBQdy2MAbuDoEP  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...
# 3  2ndOu6utnBQdy2MAbuDoEP  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...
# 4  2ndOu6utnBQdy2MAbuDoEP  ['AD', 'AR', 'AT', 'AU', 'BE', 'BG', 'BO', 'BR...
#
#    disc_number  duration_ms  explicit                      id  is_local  \
# 0            1       157000      True  71bvmZJNkV8ef3WOmpB5PT     False
# 1            1       203101     False  195VSJEUjOs1lnW0ikh89l     False
# 2            1       178258     False  3PNlW3dR7gdnMQOP4Vb8AU     False
# 3            1       177800     False  3BGbGhA498Lyz5ixwiF0rA     False
# 4            1       191167     False  4h6qJI9vuHoCscQmuVj2DJ     False
#
# ...

# %%
artists = pd.read_csv('artist.csv')

# %%
artists.head()
# Out:
#                 albums_id               artist_id         artist_name  \
# 0  5UwAcPkrtvw2YI9Z1GM4Um  7b2Me7hHhBoBGddTRSO6kk             Swayzic
# 1  2ndOu6utnBQdy2MAbuDoEP  0eEyJYLYfx1dY8rsVsNVG0  The Hip Hop Nation
# 2  2ndOu6utnBQdy2MAbuDoEP  0eEyJYLYfx1dY8rsVsNVG0  The Hip Hop Nation
# 3  2ndOu6utnBQdy2MAbuDoEP  0eEyJYLYfx1dY8rsVsNVG0  The Hip Hop Nation
# 4  2ndOu6utnBQdy2MAbuDoEP  0eEyJYLYfx1dY8rsVsNVG0  The Hip Hop Nation
#
#                 tracks_id
# 0  71bvmZJNkV8ef3WOmpB5PT
# 1  195VSJEUjOs1lnW0ikh89l
# 2  3PNlW3dR7gdnMQOP4Vb8AU
# 3  3BGbGhA498Lyz5ixwiF0rA
# 4  4h6qJI9vuHoCscQmuVj2DJ

# %%
temp = pd.merge(artists[['artist_name','tracks_id']],tracks[['name','id']],
               left_on = 'tracks_id',right_on = 'id')

# %%
temp.loc[40:60]
# Out:
#                    artist_name               tracks_id  \
# 40               Ghost Wavvves  2RuqLfmra3yuBYxehJyPdr
# 41                       Woner  2RuqLfmra3yuBYxehJyPdr
# 42  E the R&b Hip-hop Rockstar  0ptyAFzj50L7VTVzTFeTHz
# 43                Hip Hop Club  72ttuT4BX7CB7gJNbDMRP3
# 44                Hip Hop Club  1iA42IuvIMievXHmtcbROo
# 45                Hip Hop Club  7u2gT94bhcvSRcknhgM2QX
# 46                Hip Hop Club  7sSKoXfmXzFzJKhmjNltgl
# 47                Hip Hop Club  7LAOJ0u5kjzmrOp9iwDBep
# 48                Hip Hop Club  53RfTAzcEvvD8DxcUvXOzz
# 49                Hip Hop Club  7CRoc5AK4jfeFmmVYpwoRi
# 50                Hip Hop Club  0tNzOekPxYhCIYcFlScaIp
# 51                Hip Hop Club  6c6U8Eyc2ag2YT4nG421Ks
# 52                Hip Hop Club  3bNUngKqHCGnToezXp142w
# 53                Hip Hop Club  5BY2sET339k2aW0PMSxWzJ
# 54                Hip Hop Club  0TlMNvXiN7lLEN6sP5Ypvb
# 55                Hip Hop Club  3R65bhfvPoZrgJUfLS6hio
# ...

# %%
base_url = "http://api.genius.com"
headers = {
    "Authorization":'Bearer ji1pR-3jDekbfxcRY4oAuSx7TTRLW4a9BB6M4EP-Se573WVOekAhLRFiBOOZWuRF'
}
song_title = "Ragnarok (feat. Woner)"
search_url = base_url + "/search?q={}".format('%20'.join(song_title.split(' ')))
data = {'q': song_title}
response = requests.get(search_url, headers=headers)

# %%
base_url = "http://api.genius.com"
headers = {
    "Authorization":'Bearer ji1pR-3jDekbfxcRY4oAuSx7TTRLW4a9BB6M4EP-Se573WVOekAhLRFiBOOZWuRF'
}
song_title = "Ragnarok (feat. Woner)"
artist_name = 'Woner'
search_url = base_url + '/search'
searchres = {'q': song_title +' '+  artist_name}
response = requests.get(search_url,params= searchres, headers=headers)

# %%
json = response.json()

# %%
response.url
# Out:
# 'https://api.genius.com/search?q=Ragnarok+%28feat.+Woner%29+Woner'

# %%
for each in json['response']['hits']:
    print(each['result']['primary_artist']['name'])
# Out:
# Charming Disaster
# L
# Thomas Carlyle
# Snorri Sturluson
# Ragnarok
# ScopeY _/
# Screen Genius
# Cradle of Filth
# Genius Users
# B-Ly & WillFake

# %%
json['response']['hits']
# Out:
# [{'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 0,
#    'api_path': '/songs/4064396',
#    'full_title': 'Still dead, while dying by\xa0Voka',
#    'header_image_thumbnail_url': 'https://images.genius.com/b83623ae2f038494f3671bf06bb459b6.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/b83623ae2f038494f3671bf06bb459b6.500x500x1.jpg',
#    'id': 4064396,
#    'lyrics_owner_id': 4585975,
#    'lyrics_state': 'complete',
#    'path': '/Voka-still-dead-while-dying-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/b83623ae2f038494f3671bf06bb459b6.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Still dead, while dying',
#    'title_with_featured': 'Still dead, while dying',
#    'url': 'https://genius.com/Voka-still-dead-while-dying-lyrics',
#    'primary_artist': {'api_path': '/artists/628932',
# ...

# %%
from bs4 import BeautifulSoup
json = response.json()
json['response']['hits'][0]['result']['primary_artist']['name']
# Out:
# 'Voka'

# %%
lyrics = json['response']['hits'][0]['result']['url']
page = requests.get(lyrics)
html = BeautifulSoup(page.text,'html.parser')
html.find('div',class_= 'lyrics').get_text()
# Out:
# "\n\n[Part 1: still dead]\n[Chorus]\nBrains still fried, hurt myself\nSmokin' anything I want\nIt brings me peace and mindful thinking\nLetting things just happen\n\nI can't tell what's the truth\nI don’t care now\nAll I see is your face\nHaunting me now\nDon’t you hear me?\nPlease just tell me\n\n[Verse 1]\nMovin' slow with it\nSpeak my mind with it\nAin’t a feeling anymore\nItsa lifestyle\nOut to kill like sato\nRidin' building down to hell bitch\nDo this shit for fun, It’s a game\nYou're a handheld\nSomething like stain\nFeel the pain when I kill shit\nPiercin through like arrows\nUp in flames, burn the house down\nUnstable elevator fallin' through\nBut catchin' on\n\nYou can’t tag along\nVery few in my crew\nOnly two, what it do?\nYea the heads always turn\nFuck it though\nFuck you tho\nWe cannot giva shit\nAll alone like bugzy\nNobody say goodbye to me\nI’ll be like Billy Tyne\nGo down with my fuckin' boat\n\nWhatchu know about love?\nWhatchu know about connection?\nEverybody fu
# ...

# %%
lyrics
# Out:
# 'https://genius.com/Charming-disaster-ragnarok-lyrics'

# %%
json['response']['hits']
# Out:
# [{'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 0,
#    'api_path': '/songs/3863490',
#    'full_title': 'Ragnarok by\xa0Charming\xa0Disaster',
#    'header_image_thumbnail_url': 'https://images.genius.com/cfd21c6fd20a5c8014972627c8e38ad7.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/cfd21c6fd20a5c8014972627c8e38ad7.1000x1000x1.jpg',
#    'id': 3863490,
#    'lyrics_owner_id': 5661827,
#    'lyrics_state': 'complete',
#    'path': '/Charming-disaster-ragnarok-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/cfd21c6fd20a5c8014972627c8e38ad7.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Ragnarok',
#    'title_with_featured': 'Ragnarok',
#    'url': 'https://genius.com/Charming-disaster-ragnarok-lyrics',
#    'primary_artist': {'api_path': '/artists/649102',
# ...

# %%
# Out:
# "\n\n[Verse 1: Ellia Bisker & Jeff Morris]\nMaybe the world will fall apart\nMaybe the crows will come and peck away your heart\nMaybe the wolves will eat the moon and the sun\nAnd we won't have to face the consequences of the things we've done\n\n[Pre-Chorus: Ellia Bisker & Jeff Morris]\nAxe time, sword time, 'ere the world fall\nWind time, wolf time, come the end of it all\nNearly doomsday, just look at the clock\nTicking down the minutes until Ragnarok, Ragnarok\n\n[Chorus: Ellia Bisker & Jeff Morris]\nRagnarok, Ragnarok, Ragnarok\nRagnarok, Ragnarok rock\n\n[Verse 2: Ellia Bisker & Jeff Morris]\nNow that the sky is raining soot\nNo need to return all of those late library books\nThat you read with bated breath\nAbout the end where even gods can meet their death\n\n[Pre-Chorus: Ellia Bisker & Jeff Morris]\nWorld tree, tremble, shake at the root\nFall before the moment when our bills come due\nCross your fingers for fire and flood\nThe Valkyries are rushing through the battlefields
# ...

# %%
response.url
# Out:
# 'https://api.genius.com/search'

# %%
search_url
# Out:
# 'http://api.genius.com/search'

# %%
json
# Out:
# {'meta': {'status': 200}, 'response': {'hits': []}}

# %%
response = requests.get('https://spotifycharts.com/regional/us/weekly/2018-10-19--2018-10-26')

# %%
html = BeautifulSoup(response.text,'html.parser')

# %%
html
# Out:
# <!DOCTYPE doctype html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Spotify Charts</title>
# <meta content="Spotify Charts" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://www.spotifycharts.com/" property="og:url"/>
# <meta content="http://d2c87l0yth4zbw-2.global.ssl.fastly.net/i/_global/open-graph-default.png" property="og:image"/>
# <meta content="Spotify is all the music you’ll ever need." property="og:description"/>
# <meta content="Spotify is all the music you’ll ever need." name="description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/images/touch-icon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="/images/touch-icon-114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="/images/touch-icon-72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# ...
