# %%
import pandas as pd
import numpy as np
import spotipy
import os
import sys
import time
import json
import requests

# %% [markdown]
# ### Process
# **This Script gets all basic information from Spotify e.g ID relations**
# 1. Setup environment for OAuth of spotify API by this [link](https://developer.spotify.com/documentation/web-api/quick-start/)
# 2. Generate access token by the client id and client secret from Spotify web api account
# 3. Read the documentation to get data (same link in 1.)
# 4. Get album by searching key word 'Hip Hop'
# 5. Get all tracks from these album
# 6. [WordCloud](https://www.datacamp.com/community/tutorials/wordcloud-python)

# %%
# define the Oauth
sp = spotipy.Spotify(
auth ='BQDF3TiQPW_C4Ie-3aYpVltrKmv9pWhTEYidvygGKmF7dk5PgdN_NAhLYImqctyXFFcyVB1A-TcPMCCnfhsPo6E_wjwHFBvl980gUlxFM6hBKUFQkqhDPfQlBkbLxeodJWUGvlK76rDqL_uM3OyahODYhpNDUJ8q5EWxwgzbinz0GuE8lOC0SB1wp1Tr'

)

# %%
# define the limit and offset
offset = 0
limit = 50

# %%
# this block downloads data from API
now = time.time()
i = 0
file_names = 'albums_'
while i < 140000:
    i += limit
    with open('data/albums/'+ file_names + str(offset) + '.json','w') as f:
        res = sp.search(q = 'hip-hop', limit = 50,
                       type = 'album',offset = offset)
        json.dump(res,f)
        offset += limit
    
    if(i % 3000 == 0):
        print('Process {} tracks'.format(i))
# Out:
# Process 3000 tracks
# Process 6000 tracks
# Process 9000 tracks
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.5/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     118         try:
# --> 119             r.raise_for_status()
#     120         except:
#
# ~/anaconda3/lib/python3.5/site-packages/requests/models.py in raise_for_status(self)
#     938         if http_error_msg:
# --> 939             raise HTTPError(http_error_msg, response=self)
#     940
#
# HTTPError: 404 Client Error: Not Found for url: https://api.spotify.com/v1/search?limit=50&type=album&q=hip-hop&offset=10000
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-58-04f63e6e6c77> in <module>()
#       6     with open('data/albums/'+ file_names + str(offset) + '.json','w') as f:
#       7         res = sp.search(q = 'hip-hop', limit = 50,
# ----> 8                        type = 'album',offset = offset)
#       9         json.dump(res,f)
#      10         offset += limit
#
# ~/anaconda3/lib/python3.5/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     337                 - market - An ISO 3166-1 alpha-2 country code or the string from_token.
#     338         '''
# --> 339         return self._get('search', q=q, limit=limit, offset=offset, type=type, market=market)
#     340
#     341     def user(self, user):
#
# ~/anaconda3/lib/python3.5/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~/anaconda3/lib/python3.5/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     122                 raise SpotifyException(r.status_code,
#     123                     -1, '%s:\n %s' % (r.url, r.json()['error']['message']),
# --> 124                     headers=r.headers)
#     125             else:
#     126                 raise SpotifyException(r.status_code,
#
# SpotifyException: http status: 404, code:-1 - https://api.spotify.com/v1/search?limit=50&type=album&q=hip-hop&offset=10000:
#  Not found.

# %%
'''
Get all non-artist information from albums
'''
def getAllDataFromAlbum(albums):
    albums = albums['albums']['items']
    data = {
        'album_type':[],
        'available_markets':[],
        'id':[],
        'images':[],
        'name':[],
        'release_date':[],
        'total_tracks':[]
    }
    for each in albums:
        for key in data:
            if key in ['available_market']:
                data[key].append(','.join(each[key]))
            elif key in ['images']:
                if(len(each[key]) != 0):
                    data[key].append(each[key][0])
                else:
                    data[key].append(np.NaN)
            else:
                data[key].append(each[key])
    return data

# %%
direc = 'data/albums/' 
files = os.listdir('data/albums/')
files = sorted(files)

# %%
with open(direc + files[0],'r') as f:
        sample = json.load(f)
df = pd.DataFrame(getAllDataFromAlbum(sample))
for f in files[1:]:
    with open(direc + f,'r') as fp:
        sample = json.load(fp)
    
    df = df.append(pd.DataFrame(getAllDataFromAlbum(sample)))
# change the data type 
df['release_date'] = pd.to_datetime(df.release_date)

# %%
df.sort_values(by = 'release_date',ascending = False,
              inplace = True)
df.head()
# Out:
#      album_type                                  available_markets  \
# 41       single  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 49        album  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 37  compilation  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 5        single  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 44        album  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
#
#                         id                                             images  \
# 41  5UwAcPkrtvw2YI9Z1GM4Um  {'height': 640, 'url': 'https://i.scdn.co/imag...
# 49  2ndOu6utnBQdy2MAbuDoEP  {'height': 640, 'url': 'https://i.scdn.co/imag...
# 37  0RizsmoLQbi3o5ovoqedRm  {'height': 640, 'url': 'https://i.scdn.co/imag...
# 5   2OVO1VX4OQ9ZGy1110oBqX  {'height': 640, 'url': 'https://i.scdn.co/imag...
# 44  6b0P48KLaBPD3Vf7Z08ALK  {'height': 640, 'url': 'https://i.scdn.co/imag...
#
#                                     name release_date  total_tracks
# 41                           Hip Hop SZN   2018-10-20             1
# 49  Have a Hip-Hop Halloween (Only Hits)   2018-10-20            21
# 37                    Male Vocal Hip-Hop   2018-10-19            13
# 5                           Provokin' Me   2018-10-19             1
# 44   The Halloween Hip-Hop Hits Playlist   2018-10-19            21

# %%
# save the original data frame since will need to drop some of them
import pickle
saved = False
if saved:
    with open('raw_albums.pkl','wb') as fp:
        pickle.dump(df,fp)

# %%
# Total tracks in these albums
print(df.total_tracks.sum())
# Out:
# 121195

# %%
# Only look at the tracks between 2013 and 2018
df = df.loc[df.release_date > '2013']
print('Total tracks {}'.format(df.total_tracks.sum()))
# Out:
# Total tracks 74178

# %%
df.shape
# Out:
# (5222, 7)

# %%
sample = sp.album_tracks(album_id='2ndOu6utnBQdy2MAbuDoEP')

# %%
sample
# Out:
# {'href': 'https://api.spotify.com/v1/albums/2ndOu6utnBQdy2MAbuDoEP/tracks?offset=0&limit=50',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 203101,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/195VSJEUjOs1lnW0ikh89l'},
#    'href': 'https://api.spotify.com/v1/tracks/195VSJEUjOs1lnW0ikh89l',
#    'id': '195VSJEUjOs1lnW0ikh89l',
#    'is_local': False,
#    'name': 'Nice for What',
#    'preview_url': 'https://p.scdn.co/mp3-preview/14610d390cd3d12ae66f3da6f08e66de8ec2b3a3?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:195VSJEUjOs1lnW0ikh89l'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 178258,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3PNlW3dR7gdnMQOP4Vb8AU'},
#    'href': 'https://api.spotify.com/v1/tracks/3PNlW3dR7gdnMQOP4Vb8AU',
#    'id': '3PNlW3dR7gdnMQOP4Vb8AU',
#    'is_local': False,
#    'name': 'Xo Tour Llif3',
#    'preview_url': 'https://p.scdn.co/mp3-preview/2ea1aa3b420e2d298a455b056db79875745090bd?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3PNlW3dR7gdnMQOP4Vb8AU'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 177800,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3BGbGhA498Lyz5ixwiF0rA'},
#    'href': 'https://api.spotify.com/v1/tracks/3BGbGhA498Lyz5ixwiF0rA',
#    'id': '3BGbGhA498Lyz5ixwiF0rA',
#    'is_local': False,
#    'name': 'Humble',
#    'preview_url': 'https://p.scdn.co/mp3-preview/d0296a87920ebe1240efdeb1ecc1d9a725bdcb6b?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3BGbGhA498Lyz5ixwiF0rA'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 191167,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4h6qJI9vuHoCscQmuVj2DJ'},
#    'href': 'https://api.spotify.com/v1/tracks/4h6qJI9vuHoCscQmuVj2DJ',
#    'id': '4h6qJI9vuHoCscQmuVj2DJ',
#    'is_local': False,
#    'name': 'Young Dumb & Broke',
#    'preview_url': 'https://p.scdn.co/mp3-preview/94ae7fc25e25cbf91953182a4608d8074c6f0804?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:4h6qJI9vuHoCscQmuVj2DJ'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 197659,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7vClFyYSdhdMJse463E2BY'},
#    'href': 'https://api.spotify.com/v1/tracks/7vClFyYSdhdMJse463E2BY',
#    'id': '7vClFyYSdhdMJse463E2BY',
#    'is_local': False,
#    'name': 'Butterfly Effect',
#    'preview_url': 'https://p.scdn.co/mp3-preview/397fcc16f20cf3398dabb83e1af8a1a4e9f36d07?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7vClFyYSdhdMJse463E2BY'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 132250,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4tGVGX9aKQgfpaM22vP5X3'},
#    'href': 'https://api.spotify.com/v1/tracks/4tGVGX9aKQgfpaM22vP5X3',
#    'id': '4tGVGX9aKQgfpaM22vP5X3',
#    'is_local': False,
#    'name': 'Gucci Gang',
#    'preview_url': 'https://p.scdn.co/mp3-preview/c248599d52f38db2985bf3636cbb0781fe7ad433?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:4tGVGX9aKQgfpaM22vP5X3'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 217216,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Kkaq933P0fa2DmBJEG7M1'},
#    'href': 'https://api.spotify.com/v1/tracks/2Kkaq933P0fa2DmBJEG7M1',
#    'id': '2Kkaq933P0fa2DmBJEG7M1',
#    'is_local': False,
#    'name': 'Atm',
#    'preview_url': 'https://p.scdn.co/mp3-preview/875ae992ba95f5d6f2d66eaf409c9ccabde49885?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:2Kkaq933P0fa2DmBJEG7M1'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 216947,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2IGkMK01x3a9a9G5KRj9hn'},
#    'href': 'https://api.spotify.com/v1/tracks/2IGkMK01x3a9a9G5KRj9hn',
#    'id': '2IGkMK01x3a9a9G5KRj9hn',
#    'is_local': False,
#    'name': 'Lemon',
#    'preview_url': 'https://p.scdn.co/mp3-preview/0e1a7570db414d511d98119ed1e77abef9af537f?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:2IGkMK01x3a9a9G5KRj9hn'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 179361,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3um9QWuDEG2ysdOf9P5iub'},
#    'href': 'https://api.spotify.com/v1/tracks/3um9QWuDEG2ysdOf9P5iub',
#    'id': '3um9QWuDEG2ysdOf9P5iub',
#    'is_local': False,
#    'name': 'Wish',
#    'preview_url': 'https://p.scdn.co/mp3-preview/e2d120d676c94f9fa99cc16b3bf5e772e07becfb?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:3um9QWuDEG2ysdOf9P5iub'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 167931,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7gGOzvdDPZWWcNzfTpZnjk'},
#    'href': 'https://api.spotify.com/v1/tracks/7gGOzvdDPZWWcNzfTpZnjk',
#    'id': '7gGOzvdDPZWWcNzfTpZnjk',
#    'is_local': False,
#    'name': 'Color Blind',
#    'preview_url': 'https://p.scdn.co/mp3-preview/88b23b7f6425591ffc6c6e720baba13a608ddf15?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:7gGOzvdDPZWWcNzfTpZnjk'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 197452,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4HPygCckfKj8ukS4DFh7pW'},
#    'href': 'https://api.spotify.com/v1/tracks/4HPygCckfKj8ukS4DFh7pW',
#    'id': '4HPygCckfKj8ukS4DFh7pW',
#    'is_local': False,
#    'name': 'Element',
#    'preview_url': 'https://p.scdn.co/mp3-preview/45844b54337511ee76f7750ef0a7437dcaff2758?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:4HPygCckfKj8ukS4DFh7pW'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 240217,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4vvWZyA1CYfjzxjt1ckKtw'},
#    'href': 'https://api.spotify.com/v1/tracks/4vvWZyA1CYfjzxjt1ckKtw',
#    'id': '4vvWZyA1CYfjzxjt1ckKtw',
#    'is_local': False,
#    'name': 'Bad Things',
#    'preview_url': 'https://p.scdn.co/mp3-preview/4430299052888770fd490d751f76e51572ccf1b6?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:4vvWZyA1CYfjzxjt1ckKtw'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 200265,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6fs5yQspmIYARZmpMIP2A0'},
#    'href': 'https://api.spotify.com/v1/tracks/6fs5yQspmIYARZmpMIP2A0',
#    'id': '6fs5yQspmIYARZmpMIP2A0',
#    'is_local': False,
#    'name': "You Don't Own Me",
#    'preview_url': 'https://p.scdn.co/mp3-preview/95d5e6b5a85d30b60f6c90a03f9bfc664085ba39?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:6fs5yQspmIYARZmpMIP2A0'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 250884,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3LYJU4vueCu20Qut8V0qpO'},
#    'href': 'https://api.spotify.com/v1/tracks/3LYJU4vueCu20Qut8V0qpO',
#    'id': '3LYJU4vueCu20Qut8V0qpO',
#    'is_local': False,
#    'name': "I Don't Mind",
#    'preview_url': 'https://p.scdn.co/mp3-preview/05e30bb26f52883bf055647e0eeb1dfa3898755c?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:3LYJU4vueCu20Qut8V0qpO'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 231000,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2JKnl07B5OsLVpT8pgMFeW'},
#    'href': 'https://api.spotify.com/v1/tracks/2JKnl07B5OsLVpT8pgMFeW',
#    'id': '2JKnl07B5OsLVpT8pgMFeW',
#    'is_local': False,
#    'name': 'Blinded by Your Grace, Pt. 2',
#    'preview_url': 'https://p.scdn.co/mp3-preview/58b5ac5d95c5cf6e42448a569a95a57f0b1aa4e2?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:2JKnl07B5OsLVpT8pgMFeW'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 217578,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6hvHIvyMFToQPiRSuLZQay'},
#    'href': 'https://api.spotify.com/v1/tracks/6hvHIvyMFToQPiRSuLZQay',
#    'id': '6hvHIvyMFToQPiRSuLZQay',
#    'is_local': False,
#    'name': 'Bestie',
#    'preview_url': 'https://p.scdn.co/mp3-preview/03d565014346715dca6de405bb728fa7da43490a?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:6hvHIvyMFToQPiRSuLZQay'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 170373,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1niCGmSLlmkJtgtUUu0xCq'},
#    'href': 'https://api.spotify.com/v1/tracks/1niCGmSLlmkJtgtUUu0xCq',
#    'id': '1niCGmSLlmkJtgtUUu0xCq',
#    'is_local': False,
#    'name': 'I Got It',
#    'preview_url': 'https://p.scdn.co/mp3-preview/38178217d23640915e4347fb33fdca381673c57f?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 17,
#    'type': 'track',
#    'uri': 'spotify:track:1niCGmSLlmkJtgtUUu0xCq'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 279418,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7uHcOpYkFCa4JmnVsupBHB'},
#    'href': 'https://api.spotify.com/v1/tracks/7uHcOpYkFCa4JmnVsupBHB',
#    'id': '7uHcOpYkFCa4JmnVsupBHB',
#    'is_local': False,
#    'name': 'Bed of Lies',
#    'preview_url': 'https://p.scdn.co/mp3-preview/a208d884628c8d2d6d5458ee50786a8c35f28b7d?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 18,
#    'type': 'track',
#    'uri': 'spotify:track:7uHcOpYkFCa4JmnVsupBHB'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 225089,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3e4wq2tFcY08N7YmOLcFau'},
#    'href': 'https://api.spotify.com/v1/tracks/3e4wq2tFcY08N7YmOLcFau',
#    'id': '3e4wq2tFcY08N7YmOLcFau',
#    'is_local': False,
#    'name': 'Feel Right',
#    'preview_url': 'https://p.scdn.co/mp3-preview/713cca4e7226f29be51fc11f375d4faca207147d?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 19,
#    'type': 'track',
#    'uri': 'spotify:track:3e4wq2tFcY08N7YmOLcFau'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 206944,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4e23o1A8rGdmK8CsmaEGDs'},
#    'href': 'https://api.spotify.com/v1/tracks/4e23o1A8rGdmK8CsmaEGDs',
#    'id': '4e23o1A8rGdmK8CsmaEGDs',
#    'is_local': False,
#    'name': 'Run Up',
#    'preview_url': 'https://p.scdn.co/mp3-preview/83e6ffe107a52e8dcb8787e2ad68182ac3edf7d6?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 20,
#    'type': 'track',
#    'uri': 'spotify:track:4e23o1A8rGdmK8CsmaEGDs'},
#   {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#      'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#      'id': '0eEyJYLYfx1dY8rsVsNVG0',
#      'name': 'The Hip Hop Nation',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'RO',
#     'SE',
#     'SG',
#     'SK',
#     'SV',
#     'TH',
#     'TR',
#     'TW',
#     'US',
#     'UY',
#     'VN',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 197210,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3PfneVylGRZk4e2CnEQ2d5'},
#    'href': 'https://api.spotify.com/v1/tracks/3PfneVylGRZk4e2CnEQ2d5',
#    'id': '3PfneVylGRZk4e2CnEQ2d5',
#    'is_local': False,
#    'name': '679',
#    'preview_url': 'https://p.scdn.co/mp3-preview/b6f94a121b2e1d480b56f35e5a511289edf86e58?cid=7766cd7a9a4a45319a2a307f0f83e732',
#    'track_number': 21,
#    'type': 'track',
#    'uri': 'spotify:track:3PfneVylGRZk4e2CnEQ2d5'}],
#  'limit': 50,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 21}

# %%
def getTracksFromAlbum(album_id):
    total_tracks = df.loc[df.id == each].total_tracks.values[0]
    data = sp.album_tracks(album_id=album_id,
                          limit = 50)
    return data

# %%
tracks_data = {
    'num_of_artists':[],
    'available_markets':[],
    'disc_number':[],
    'duration_ms':[],
    'explicit':[],
    'is_local':[],
    'id':[],
    'name':[],
    'track_number':[],
    'album_id':[]
}

for each in df.id.tolist():
    tracks = getTracksFromAlbum(each)['items']
    
    for track in tracks:
        for key in tracks_data:
            if key == 'num_of_artists':
                tracks_data[key].append(len(track['artists']))
            elif key == 'album_id':
                tracks_data[key].append(each)
            else:
                tracks_data[key].append(track[key])
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs

# %%
sample['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0eEyJYLYfx1dY8rsVsNVG0'},
#   'href': 'https://api.spotify.com/v1/artists/0eEyJYLYfx1dY8rsVsNVG0',
#   'id': '0eEyJYLYfx1dY8rsVsNVG0',
#   'name': 'The Hip Hop Nation',
#   'type': 'artist',
#   'uri': 'spotify:artist:0eEyJYLYfx1dY8rsVsNVG0'}]

# %%
sample['items'][0]['id']
# Out:
# '195VSJEUjOs1lnW0ikh89l'

# %%
tracks_df = pd.DataFrame(tracks_data)

# %%
print(tracks_df.shape)
# Out:
# (69846, 10)

# %%
# get artist data
artists_data = {
    'tracks_id':[],
    'albums_id':[],
    'artist_id':[],
    'artist_name':[]
}
i = 0
for each in df.id.tolist(): # for each album id
    tracks = getTracksFromAlbum(each)['items']
    i +=1
    if i % 3000 == 0:
        print('Process {}'.format(i))
    for track in tracks:
        artists = track['artists']
        for artist in artists:
            artists_data['tracks_id'].append(track['id'])
            artists_data['albums_id'].append(each)
            artists_data['artist_name'].append(artist['name'])
            artists_data['artist_id'].append(artist['id'])
# Out:
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# Process 3000
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs
# retrying ...1secs

# %%
artists_df = pd.DataFrame(artists_data)

# %%
artists_df.artist_name.unique().shape
# Out:
# (12982,)

# %%
saved = False
if saved:
    with open('raw_artists.pkl','wb') as fp:
        pickle.dump(artists_df,fp)

# %%
artists_df.to_csv('artist.csv',
                 index = False)

# %%
artists_df.head()
# Out:
#                 albums_id               artist_id         artist_name  \
# 0  5UwAcPkrtvw2YI9Z1GM4Um  7b2Me7hHhBoBGddTRSO6kk             Swayzic
# 1  2ndOu6utnBQdy2MAbuDoEP  0eEyJYLYfx1dY8rsVsNVG0  The Hip Hop Nation
# 2  2ndOu6utnBQdy2MAbuDoEP  0eEyJYLYfx1dY8rsVsNVG0  The Hip Hop Nation
# 3  2ndOu6utnBQdy2MAbuDoEP  0eEyJYLYfx1dY8rsVsNVG0  The Hip Hop Nation
# 4  2ndOu6utnBQdy2MAbuDoEP  0eEyJYLYfx1dY8rsVsNVG0  The Hip Hop Nation
#
#                 tracks_id
# 0  71bvmZJNkV8ef3WOmpB5PT
# 1  195VSJEUjOs1lnW0ikh89l
# 2  3PNlW3dR7gdnMQOP4Vb8AU
# 3  3BGbGhA498Lyz5ixwiF0rA
# 4  4h6qJI9vuHoCscQmuVj2DJ

# %%
tracks_df.head()
# Out:
#                  album_id                                  available_markets  \
# 0  5UwAcPkrtvw2YI9Z1GM4Um  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 1  2ndOu6utnBQdy2MAbuDoEP  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 2  2ndOu6utnBQdy2MAbuDoEP  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 3  2ndOu6utnBQdy2MAbuDoEP  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 4  2ndOu6utnBQdy2MAbuDoEP  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
#
#    disc_number  duration_ms  explicit                      id  is_local  \
# 0            1       157000      True  71bvmZJNkV8ef3WOmpB5PT     False
# 1            1       203101     False  195VSJEUjOs1lnW0ikh89l     False
# 2            1       178258     False  3PNlW3dR7gdnMQOP4Vb8AU     False
# 3            1       177800     False  3BGbGhA498Lyz5ixwiF0rA     False
# 4            1       191167     False  4h6qJI9vuHoCscQmuVj2DJ     False
#
#                  name  num_of_artists  track_number
# 0         Hip Hop SZN               1             1
# 1       Nice for What               1             1
# 2       Xo Tour Llif3               1             2
# 3              Humble               1             3
# 4  Young Dumb & Broke               1             4

# %%
df.head()
# Out:
#      album_type                                  available_markets  \
# 41       single  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 49        album  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 37  compilation  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 5        single  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
# 44        album  [AD, AR, AT, AU, BE, BG, BO, BR, CA, CH, CL, C...
#
#                         id                                             images  \
# 41  5UwAcPkrtvw2YI9Z1GM4Um  {'height': 640, 'url': 'https://i.scdn.co/imag...
# 49  2ndOu6utnBQdy2MAbuDoEP  {'height': 640, 'url': 'https://i.scdn.co/imag...
# 37  0RizsmoLQbi3o5ovoqedRm  {'height': 640, 'url': 'https://i.scdn.co/imag...
# 5   2OVO1VX4OQ9ZGy1110oBqX  {'height': 640, 'url': 'https://i.scdn.co/imag...
# 44  6b0P48KLaBPD3Vf7Z08ALK  {'height': 640, 'url': 'https://i.scdn.co/imag...
#
#                                     name release_date  total_tracks
# 41                           Hip Hop SZN   2018-10-20             1
# 49  Have a Hip-Hop Halloween (Only Hits)   2018-10-20            21
# 37                    Male Vocal Hip-Hop   2018-10-19            13
# 5                           Provokin' Me   2018-10-19             1
# 44   The Halloween Hip-Hop Hits Playlist   2018-10-19            21

# %%
# Saved Tracks here
saved = False
if saved:
    with open('raw_tracks.pkl','wb') as fp:
        pickle.dump(tracks_df,fp)

# %%
# Save files into csv
df.to_csv('albums.csv',
         index = False)
tracks_df.to_csv('tracks.csv',
                index = False)

# %%
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
mask = np.array(Image.open('dancer.png'))

# %%
# generate wordcloud
text = ' '.join(tracks_df.name)
stopwords = set(STOPWORDS)

wordcloud =  WordCloud(
    collocations = False,
    width = 800,
    height = 400,
    stopwords=stopwords,
    background_color = 'white').generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
wordcloud.to_file('cloud1.png')
plt.show()
